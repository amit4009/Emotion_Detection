# %% [markdown]
# # Emotion Detection from scratch

# %% [markdown]
# # Data Set-
#
# Kaggle - https://www.kaggle.com/datasets/msambare/fer2013
# The data consists of 48x48 pixel grayscale images of faces. The faces have been automatically registered so that the face is more or less centred and occupies about the same amount of space in each image.
#
# The task is to categorize each face based on the emotion shown in the facial expression into one of seven categories (0=Angry, 1=Disgust, 2=Fear, 3=Happy, 4=Sad, 5=Surprise, 6=Neutral)

# %%
import tensorflow as tf
print("Tensorflow version " + tf.__version__)

try:
  tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  # TPU detection
  print(f'Running on a TPU w/{tpu.num_accelerators()["TPU"]} cores')
except ValueError:
  raise BaseException('ERROR: Not connected to a TPU runtime; please see the previous cell in this notebook for instructions!')

tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
tpu_strategy = tf.distribute.TPUStrategy(tpu)
# Out:
# Tensorflow version 2.15.0
# Running on a TPU w/8 cores

# %% [markdown]
# # Setting up Kaggle Directory

# %%
# !pip install opendatasets
# Out:
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from opendatasets) (4.66.4)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (from opendatasets) (1.6.14)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from opendatasets) (8.1.7)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.31.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle->opendatasets) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle->opendatasets) (3.7)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22

# %%
import opendatasets as od
od.download("https://www.kaggle.com/datasets/msambare/fer2013")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: amitpandit1
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# Downloading fer2013.zip to ./fer2013
# 100%|██████████| 60.3M/60.3M [00:00<00:00, 127MB/s]

# %%
import zipfile
import os

# %%
import os

# Path to the extracted dataset directory
extracted_path = './fer2013'

# List the files and directories in the extracted path
for root, dirs, files in os.walk(extracted_path):
    print(f'Root: {root}')
    for name in files:
        print(f'File: {os.path.join(root, name)}')
    for name in dirs:
        print(f'Dir: {os.path.join(root, name)}')
# Out:
# Streaming output truncated to the last 5000 lines.
# File: ./fer2013/train/happy/Training_95023380.jpg
# File: ./fer2013/train/happy/Training_82515477.jpg
# File: ./fer2013/train/happy/Training_55245077.jpg
# File: ./fer2013/train/happy/Training_21876325.jpg
# File: ./fer2013/train/happy/Training_86684937.jpg
# File: ./fer2013/train/happy/Training_87183410.jpg
# File: ./fer2013/train/happy/Training_74038421.jpg
# File: ./fer2013/train/happy/Training_54965496.jpg
# File: ./fer2013/train/happy/Training_89854696.jpg
# File: ./fer2013/train/happy/Training_4997318.jpg
# File: ./fer2013/train/happy/Training_96082304.jpg
# File: ./fer2013/train/happy/Training_7321943.jpg
# File: ./fer2013/train/happy/Training_52579776.jpg
# File: ./fer2013/train/happy/Training_14866954.jpg
# File: ./fer2013/train/happy/Training_54041025.jpg
# File: ./fer2013/train/happy/Training_13235036.jpg
# File: ./fer2013/train/happy/Training_16513509.jpg
# File: ./fer2013/train/happy/Training_98887482.jpg
# File: ./fer2013/train/happy/Training_11000538.jpg
# File: ./fer2013/train/happy/Training_14489599.jpg
# File: ./fer2013/train/happy/Training_93259646.jpg
# File: ./fer2013/train/happy/Training_87865303.jpg
# File: ./fer2013/train/happy/Training_20486844.jpg
# File: ./fer2013/train/happy/Training_89354604.jpg
# File: ./fer2013/train/happy/Training_75422870.jpg
# File: ./fer2013/train/happy/Training_15570450.jpg
# File: ./fer2013/train/happy/Training_95405690.jpg
# File: ./fer2013/train/happy/Training_13867633.jpg
# File: ./fer2013/train/happy/Training_97688286.jpg
# File: ./fer2013/train/happy/Training_33464595.jpg
# File: ./fer2013/train/sad/Training_86208751.jpg
# File: ./fer2013/train/sad/Training_52461957.jpg
# File: ./fer2013/train/sad/Training_98058106.jpg
# File: ./fer2013/train/sad/Training_20029979.jpg
# File: ./fer2013/train/sad/Training_19831194.jpg
# File: ./fer2013/train/sad/Training_14259665.jpg
# File: ./fer2013/train/sad/Training_38539273.jpg
# File: ./fer2013/train/sad/Training_39479463.jpg
# File: ./fer2013/train/sad/Training_27754953.jpg
# File: ./fer2013/train/sad/Training_35324101.jpg
# File: ./fer2013/train/sad/Training_78637258.jpg
# File: ./fer2013/train/sad/Training_23016278.jpg

# %%
import pandas as pd
#df = pd.read_csv("")

# %% [markdown]
# # Installing Packages

# %%
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import imghdr
import tensorflow as tf
from PIL import Image
import seaborn as sns

from sklearn.metrics import confusion_matrix, classification_report, roc_curve, auc
from sklearn.utils.class_weight import compute_class_weight

from tensorflow.keras import layers, models, regularizers, optimizers
from tensorflow.keras.applications import VGG16, ResNet50V2
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, TensorBoard, CSVLogger
from tensorflow.keras.layers import Conv2D, MaxPooling2D, BatchNormalization, Dropout, Flatten, Dense, Activation, GlobalAveragePooling2D
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array
from keras.utils import plot_model

# %% [markdown]
# # Setting up Directory to save model data.

# %%
os.makedirs('test_dir', exist_ok=True)

# %%
# Define your project name
project_name = 'FER_2013_Emotion_Detection'

# List your models
model_names = [
    'Custom_CNN_From_Scratch',
    'Custom_CNN_With_Augmentation',
    'VGG16_Transfer_Learning',
    'ResNet50_Transfer_Learning'
]

# Base directory (in this case, Google Colab workspace)
base_dir = '/content/'

# Create the project directory
project_dir = os.path.join(base_dir, project_name)
os.makedirs(project_dir, exist_ok=True)

# Create a subdirectory for each model
for each_model in model_names:
    model_dir = os.path.join(project_dir, each_model)
    os.makedirs(model_dir, exist_ok=True)
    # Example subdirectories for model-related files
    # os.makedirs(os.path.join(model_dir, 'checkpoints'), exist_ok=True)
    # os.makedirs(os.path.join(model_dir, 'logs'), exist_ok=True)
    # os.makedirs(os.path.join(model_dir, 'saved_models'), exist_ok=True)

print(f'Project directory structure created at: {project_dir}')
# Out:
# Project directory structure created at: /content/FER_2013_Emotion_Detection

# %% [markdown]
# # Data Cleaning

# %%
# Define the list of acceptable image extensions
image_exts = ['jpeg', 'jpg', 'png']

# Path to the directory containing image classes and possibly other nested subdirectories
data_dir = '/content/fer2013/train'

# Walk through all directories and files in the dataset
for root, dirs, files in os.walk(data_dir):
    for file in files:
        # Construct the path to the current file
        file_path = os.path.join(root, file)

        try:
            # Check the file type of the current file
            file_type = imghdr.what(file_path)

            # If the file extension is not in the allowed list, remove it
            if file_type not in image_exts:
                print(f'Image not in ext list {file_path}')
                os.remove(file_path)
            else:
                # Proceed to process the image if needed, for example, reading it with OpenCV
                img = cv2.imread(file_path)

        except Exception as e:
            # Print out the issue and the path of the problematic file
            print(f'Issue with file {file_path}. Error: {e}')
            # Optionally, remove files that cause exceptions
            os.remove(file_path)

# %% [markdown]
# # Data Analysis

# %%
# Define a function to count the number of files (assumed to be images for this context) for each subdirectory in a given directory.
# The function returns a DataFrame with these counts, indexed by a specified set name (e.g., 'train' or 'test').
def count_files_in_subdirs(directory, set_name):
    # Initialize an empty dictionary to hold the count of files for each subdirectory.
    counts = {}

    # Iterate over each item in the given directory.
    for item in os.listdir(directory):
        # Construct the full path to the item.
        item_path = os.path.join(directory, item)

        # Check if the item is a directory.
        if os.path.isdir(item_path):
            # Count the number of files in the subdirectory and add it to the dictionary.
            counts[item] = len(os.listdir(item_path))

    # Convert the counts dictionary to a DataFrame for easy viewing and analysis.
    # The index of the DataFrame is set to the provided set name.
    df = pd.DataFrame(counts, index=[set_name])
    return df

# Paths to the training and testing directories.
train_dir = '/content/fer2013/train'
test_dir = '/content/fer2013/test'

# Count the files in the subdirectories of the training directory and print the result.
train_count = count_files_in_subdirs(train_dir, 'train')
print(train_count)

# Count the files in the subdirectories of the testing directory and print the result.
test_count = count_files_in_subdirs(test_dir, 'test')
print(test_count)
# Out:
#        neutral  surprise  angry  fear  disgust  happy   sad
# train     4965      3171   3995  4097      436   7215  4830
#       neutral  surprise  angry  fear  disgust  happy   sad
# test     1233       831    958  1024      111   1774  1247

# %%
train_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %%
test_count.transpose().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# # Plotting one image from each emotion.

# %%
emotions = os.listdir(train_dir)
plt.figure(figsize=(15,10))

for i, emotion in enumerate(emotions, 1):
    folder = os.path.join(train_dir, emotion)
    img_path = os.path.join(folder, os.listdir(folder)[42])
    img = plt.imread(img_path)
    plt.subplot(3, 4, i)
    plt.imshow(img, cmap='gray')
    plt.title(emotion)
    plt.axis('off')

# %% [markdown]
# # Plotting random images from given directory

# %%
def plot_images_from_directory(directory_path, class_name, num_images=9):
    # Retrieve list of all file names in the directory
    image_filenames = os.listdir(directory_path)

    # If there are fewer images than requested, we'll just show them all
    if len(image_filenames) < num_images:
        print(f"Only found {len(image_filenames)} images in {directory_path}, displaying them all.")
        num_images = len(image_filenames)

    # Randomly select 'num_images' number of file names
    selected_images = random.sample(image_filenames, num_images)

    # Plotting the images
    fig, axes = plt.subplots(3, 3, figsize=(5, 5))  # Adjust the size as needed
    axes = axes.ravel()

    for i, image_file in enumerate(selected_images):
        image_path = os.path.join(directory_path, image_file)
        # image = Image.open(image_path)
        image = load_img(image_path)
        axes[i].imshow(image)
        axes[i].set_title(f"Image: {class_name}")
        axes[i].axis('off')  # Hide the axis

    plt.tight_layout()
    plt.show()

# %%
# Placeholder for the directory path
angry_directory_path = '/content/fer2013/train/angry'  
plot_images_from_directory(angry_directory_path, class_name = 'Angry')

# %%
# Placeholder for the directory path
disgust_directory_path = '/content/fer2013/train/disgust'  
plot_images_from_directory(disgust_directory_path, class_name = 'Disgust')

# %%
# Placeholder for the directory path
surpirse_directory_path = '/content/fer2013/train/surprise'  
plot_images_from_directory(surpirse_directory_path, class_name = 'Surpirse')

# %% [markdown]
# # Checking shapes and channels.

# %%
image = '/content/fer2013/train/angry/Training_10118481.jpg'

import cv2

img = cv2.imread(image) # Default load in color format.

# If the image is loaded successfully, print its pixel values
if img is not None:
    # print(img)
    print("Shape:", img.shape)
else:
    print("The image could not be loaded. Please check the path and file permissions.")
# Out:
# Shape: (48, 48, 3)

# %%
import cv2

image_path = '/content/fer2013/train/angry/Training_10118481.jpg'

# Load the image in grayscale
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# If the image is loaded successfully, print its pixel values
if img is not None:
    # print(img)
    print("Shape:", img.shape)  # This should now print (48, 48)
else:
    print("The image could not be loaded. Please check the path and file permissions.")
# Out:
# Shape: (48, 48)

# %% [markdown]
# # Model 1 : Custom CNN from Scratch

# %% [markdown]
# ## Initializing the ImageGenerators

# %%
# Define paths to the train and validation directories
train_data_dir = '/content/fer2013/train'
test_data_dir = '/content/fer2013/test'

# %%
# Set some parameters
img_width, img_height = 48, 48  # Size of images
batch_size = 64
epochs = 10
num_classes = 7  # Update this based on the number of your classes

# %%
# Rescale the pixel values (0-255) to the [0, 1] interval
data_generator = ImageDataGenerator(rescale=1./255,
                                    validation_split=0.2)

# Automatically retrieve images and their classes for train and validation sets
train_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='training')

validation_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='validation')

test_generator = data_generator.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',)
    # subset='validation')
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Accessing class labels for the training data
train_class_labels = train_generator.class_indices
print("Training class labels:", train_class_labels)

# Accessing class labels for the validation data
validation_class_labels = validation_generator.class_indices
print("Validation class labels:", validation_class_labels)

# Accessing class labels for the validation data
test_class_labels = test_generator.class_indices
print("Validation class labels:", test_class_labels)
# Out:
# Training class labels: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
# Validation class labels: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}
# Validation class labels: {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}

# %%
# Initialising the CNN
model = Sequential()

# Adding convolutional layers with activations on the same line for clarity
model.add(Conv2D(32, kernel_size=(3, 3),kernel_initializer="glorot_uniform", padding='same', input_shape=(img_width, img_height, 1)))
model.add(Activation('relu'))
model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(Conv2D(256, kernel_size=(3, 3), kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening and adding dense layers
model.add(Flatten())
model.add(Dense(1024))
model.add(Activation('relu'))
model.add(Dropout(0.5))

# Output layer
model.add(Dense(num_classes))
model.add(Activation('softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  activation_1 (Activation)   (None, 48, 48, 64)        0
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  activation_2 (Activation)   (None, 24, 24, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 256)       295168
#
#  activation_3 (Activation)   (None, 22, 22, 256)       0
#
#  batch_normalization_1 (Bat  (None, 22, 22, 256)       1024
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 11, 11, 256)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 512)       1180160
#
#  activation_4 (Activation)   (None, 11, 11, 512)       0
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 512)       2359808
#
#  activation_5 (Activation)   (None, 11, 11, 512)       0
#
#  batch_normalization_2 (Bat  (None, 11, 11, 512)       2048
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 5, 512)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 5, 5, 512)         0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 1024)              13108224
#
#  activation_6 (Activation)   (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
#  activation_7 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 17046535 (65.03 MB)
# Trainable params: 17044871 (65.02 MB)
# Non-trainable params: 1664 (6.50 KB)
# _________________________________________________________________

# %%
# Compiling the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  activation_1 (Activation)   (None, 48, 48, 64)        0
#
#  batch_normalization (Batch  (None, 48, 48, 64)        256
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 64)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       73856
#
#  activation_2 (Activation)   (None, 24, 24, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 22, 22, 256)       295168
#
#  activation_3 (Activation)   (None, 22, 22, 256)       0
#
#  batch_normalization_1 (Bat  (None, 22, 22, 256)       1024
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 11, 11, 256)       0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 11, 11, 256)       0
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 512)       1180160
#
#  activation_4 (Activation)   (None, 11, 11, 512)       0
#
#  conv2d_5 (Conv2D)           (None, 11, 11, 512)       2359808
#
#  activation_5 (Activation)   (None, 11, 11, 512)       0
#
#  batch_normalization_2 (Bat  (None, 11, 11, 512)       2048
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 5, 5, 512)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 5, 5, 512)         0
#
#  flatten (Flatten)           (None, 12800)             0
#
#  dense (Dense)               (None, 1024)              13108224
#
#  activation_6 (Activation)   (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_1 (Dense)             (None, 7)                 7175
#
#  activation_7 (Activation)   (None, 7)                 0
#
# =================================================================
# Total params: 17046535 (65.03 MB)
# Trainable params: 17044871 (65.02 MB)
# Non-trainable params: 1664 (6.50 KB)
# _________________________________________________________________

# %%
pip install pydot
# Out:
# Requirement already satisfied: pydot in /usr/local/lib/python3.10/dist-packages (2.0.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.10/dist-packages (from pydot) (3.1.2)

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (0.20.3)

# %%
plot_model(model, to_file = '/content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Architecture.png',
           show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# # Understanding Callbacks

# %%
# File path for the model checkpoint
cnn_path = '/content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch'
name = 'Custom_CNN_model.keras'
chk_path = os.path.join(cnn_path, name)
chk_path
# Out:
# '/content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras'

# %%
# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# %%
# Callback for early stopping
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True)

# %%
# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=6,
                              verbose=1,
                              min_delta=0.0001)

# %%
# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# %%
# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, reduce_lr, csv_logger]  # Adjusted as per your use-case

# %% [markdown]
# # Calculating Steps for epoch

# %%
train_generator.samples
# Out:
# 22968

# %%
train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

# %% [markdown]
# # Model Training

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=train_steps_per_epoch,
    epochs=10,
    validation_data=validation_generator,
    validation_steps=validation_steps_epoch,
    callbacks=callbacks)
# Out:
# Epoch 1/10
# 359/359 [==============================] - ETA: 0s - loss: 12.5155 - accuracy: 0.2662
# Epoch 1: val_loss improved from inf to 11.91442, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras
# 359/359 [==============================] - 155s 426ms/step - loss: 12.5155 - accuracy: 0.2662 - val_loss: 11.9144 - val_accuracy: 0.2052 - lr: 1.0000e-04
# Epoch 2/10
# 359/359 [==============================] - ETA: 0s - loss: 10.3728 - accuracy: 0.3392
# Epoch 2: val_loss improved from 11.91442 to 9.62582, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras
# 359/359 [==============================] - 151s 419ms/step - loss: 10.3728 - accuracy: 0.3392 - val_loss: 9.6258 - val_accuracy: 0.3588 - lr: 1.0000e-04
# Epoch 3/10
# 359/359 [==============================] - ETA: 0s - loss: 8.4122 - accuracy: 0.3821
# Epoch 3: val_loss improved from 9.62582 to 7.51123, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras
# 359/359 [==============================] - 151s 420ms/step - loss: 8.4122 - accuracy: 0.3821 - val_loss: 7.5112 - val_accuracy: 0.4240 - lr: 1.0000e-04
# Epoch 4/10
# 359/359 [==============================] - ETA: 0s - loss: 6.6949 - accuracy: 0.4163
# Epoch 4: val_loss improved from 7.51123 to 5.97221, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras
# 359/359 [==============================] - 150s 418ms/step - loss: 6.6949 - accuracy: 0.4163 - val_loss: 5.9722 - val_accuracy: 0.4513 - lr: 1.0000e-04
# Epoch 5/10
# 359/359 [==============================] - ETA: 0s - loss: 5.3051 - accuracy: 0.4453
# Epoch 5: val_loss improved from 5.97221 to 4.85108, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras
# 359/359 [==============================] - 150s 418ms/step - loss: 5.3051 - accuracy: 0.4453 - val_loss: 4.8511 - val_accuracy: 0.4010 - lr: 1.0000e-04
# Epoch 6/10
# 359/359 [==============================] - ETA: 0s - loss: 4.2164 - accuracy: 0.4772
# Epoch 6: val_loss improved from 4.85108 to 3.76540, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras
# 359/359 [==============================] - 149s 416ms/step - loss: 4.2164 - accuracy: 0.4772 - val_loss: 3.7654 - val_accuracy: 0.4964 - lr: 1.0000e-04
# Epoch 7/10
# 359/359 [==============================] - ETA: 0s - loss: 3.4069 - accuracy: 0.4987
# Epoch 7: val_loss improved from 3.76540 to 3.07045, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras
# 359/359 [==============================] - 151s 421ms/step - loss: 3.4069 - accuracy: 0.4987 - val_loss: 3.0704 - val_accuracy: 0.5187 - lr: 1.0000e-04
# Epoch 8/10
# 359/359 [==============================] - ETA: 0s - loss: 2.8110 - accuracy: 0.5222
# Epoch 8: val_loss improved from 3.07045 to 2.64336, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras
# 359/359 [==============================] - 150s 419ms/step - loss: 2.8110 - accuracy: 0.5222 - val_loss: 2.6434 - val_accuracy: 0.4989 - lr: 1.0000e-04
# Epoch 9/10
# 359/359 [==============================] - ETA: 0s - loss: 2.3681 - accuracy: 0.5517
# Epoch 9: val_loss improved from 2.64336 to 2.30435, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras
# 359/359 [==============================] - 152s 422ms/step - loss: 2.3681 - accuracy: 0.5517 - val_loss: 2.3043 - val_accuracy: 0.5245 - lr: 1.0000e-04
# Epoch 10/10
# 359/359 [==============================] - ETA: 0s - loss: 2.0645 - accuracy: 0.5726
# Epoch 10: val_loss improved from 2.30435 to 2.10065, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras
# 359/359 [==============================] - 150s 418ms/step - loss: 2.0645 - accuracy: 0.5726 - val_loss: 2.1006 - val_accuracy: 0.5276 - lr: 1.0000e-04

# %% [markdown]
# # Plotting Performance Metrics

# %%
def plot_training_history(history):
    """
    Plots the training and validation accuracy and loss.

    Parameters:
    - history: A Keras History object. Contains the logs from the training process.

    Returns:
    - None. Displays the matplotlib plots for training/validation accuracy and loss.
    """
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs_range = range(len(acc))

    plt.figure(figsize=(20, 5))

    # Plot training and validation accuracy
    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, acc, label='Training Accuracy')
    plt.plot(epochs_range, val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.title('Training and Validation Accuracy')

    # Plot training and validation loss
    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, loss, label='Training Loss')
    plt.plot(epochs_range, val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.title('Training and Validation Loss')

    plt.show()

# %%
plot_training_history(history)

# %% [markdown]
# # Model Evaluation

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 359/359 [==============================] - 19s 54ms/step - loss: 1.8858 - accuracy: 0.6004
# 113/113 [==============================] - 6s 54ms/step - loss: 2.0816 - accuracy: 0.5316
# final train accuracy = 60.04 , validation accuracy = 53.16

# %% [markdown]
# # Plotting Confusion Matrix

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=np.ceil(test_generator.samples/test_generator.batch_size)), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 113/113 [==============================] - 6s 53ms/step

# %%
# Printing the classification report
report = classification_report(true_classes, predicted_classes, target_names=class_labels)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.12      0.06      0.08       958
#      disgust       0.06      0.01      0.02       111
#         fear       0.14      0.06      0.08      1024
#        happy       0.24      0.37      0.29      1774
#      neutral       0.18      0.28      0.22      1233
#          sad       0.18      0.10      0.13      1247
#     surprise       0.12      0.14      0.13       831
#
#     accuracy                           0.19      7178
#    macro avg       0.15      0.14      0.13      7178
# weighted avg       0.17      0.19      0.17      7178

# %% [markdown]
# # Making Predictions

# %%
# Emotion classes for the dataset
Emotion_Classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# Assuming test_generator and model are already defined
batch_size = test_generator.batch_size

# Selecting a random batch from the test generator
Random_batch = np.random.randint(0, len(test_generator) - 1)

# Selecting random image indices from the batch
Random_Img_Index = np.random.randint(0, batch_size, 10)

# Setting up the plot
fig, axes = plt.subplots(nrows=2, ncols=5, figsize=(10, 5),
                         subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    # Fetching the random image and its label
    Random_Img = test_generator[Random_batch][0][Random_Img_Index[i]]
    Random_Img_Label = np.argmax(test_generator[Random_batch][1][Random_Img_Index[i]], axis=0)

    # Making a prediction using the model
    Model_Prediction = np.argmax(model.predict(tf.expand_dims(Random_Img, axis=0), verbose=0), axis=1)[0]

    # Displaying the image
    ax.imshow(Random_Img.squeeze(), cmap='gray')  # Assuming the images are grayscale
    # Setting the title with true and predicted labels, colored based on correctness
    color = "green" if Emotion_Classes[Random_Img_Label] == Emotion_Classes[Model_Prediction] else "red"
    ax.set_title(f"True: {Emotion_Classes[Random_Img_Label]}\nPredicted: {Emotion_Classes[Model_Prediction]}", color=color)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Model 2: Image Augmentation

# %%
# Define paths to the train and validation directories
train_data_dir = '/content/fer2013/train'
test_data_dir = '/content/fer2013/test'
# validation_data_dir = '/content/emotion_detection_project/datasets/raw/test'

# Set some parameters
img_width, img_height = 48, 48  # Size of images
batch_size = 64
epochs = 10
num_classes = 7  # Update this based on the number of your classes


# Initializing the ImageDataGenerator with data augmentation options for the training set
data_generator = ImageDataGenerator(
    rescale=1./255,  # Rescale the pixel values from [0, 255] to [0, 1]
    rotation_range=40,  # Degree range for random rotations
    width_shift_range=0.2,  # Range (as a fraction of total width) for random horizontal shifts
    height_shift_range=0.2,  # Range (as a fraction of total height) for random vertical shifts
    shear_range=0.2,  # Shearing intensity (shear angle in counter-clockwise direction)
    zoom_range=0.2,  # Range for random zoom
    horizontal_flip=True,  # Randomly flip inputs horizontally
    fill_mode='nearest',  # Strategy to fill newly created pixels, which can appear after a rotation or a width/height shift
    validation_split=0.2  # Set the validation split; 20% of the data will be used for validation
)

test_data_generator = ImageDataGenerator(rescale=1./255)


# Automatically retrieve images and their classes for train and validation sets
train_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='training')

validation_generator = data_generator.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale',
    subset='validation')

test_generator = test_data_generator.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    color_mode='grayscale'
    )
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
# Path to your specific image
image_path = '/content/fer2013/train/angry/Training_10118481.jpg'

# Load and convert the image to an array
img = load_img(image_path, color_mode='grayscale', target_size=(img_width, img_height))  # Adjust color_mode if necessary
img_array = img_to_array(img)  # Converts the image to a numpy array
img_array = img_array.reshape((1,) + img_array.shape)  # Reshapes the image to (1, width, height, channels) for the generator

# Setting up the plot
fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(10, 4))
# Plot the original image first. Since img_array is a 3D array after reshaping, we use [:, :, 0]
axes[0].imshow(img_array[0, :, :, 0], cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')

# Generate and plot augmented images
for i, ax in enumerate(axes.flat[1:]):  # Start from the second subplot
    # Generate a batch of augmented images
    aug_iter = data_generator.flow(img_array, batch_size=1)
    aug_img = next(aug_iter)[0]  # Get the first augmented image from the batch

    # Plot the augmented image. We directly use [:, :, 0] without an initial batch index
    ax.imshow(aug_img[:, :, 0], cmap='gray')
    ax.set_title(f'Augmented Image {i+1}')
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Same CNN Model as above

# %%
# Assuming img_width, img_height, and classes are defined. For example:
img_width, img_height = 48, 48
classes = 7

#Initialising the CNN
model = tf.keras.models.Sequential()

# Adding convolutional layers with activations on separate lines
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', input_shape=(img_width, img_height, 1)))
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv2D(64, kernel_size=(3, 3), padding='same'))
model.add(tf.keras.layers.Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(2, 2))
model.add(Dropout(0.25))

model.add(Conv2D(128, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv2D(256, kernel_size=(3, 3), kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(Conv2D(512, kernel_size=(3, 3), padding='same', kernel_regularizer=regularizers.l2(0.01)))
model.add(tf.keras.layers.Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

# Flattening and adding dense layers
model.add(Flatten())
model.add(Dense(1024))
model.add(tf.keras.layers.Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(classes))
model.add(tf.keras.layers.Activation('softmax'))

# Compiling the model
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])


# File path for the model checkpoint
cnn_path = '/content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation'
name = 'Custom_CNN_augmented_model.keras'
chk_path = os.path.join(cnn_path, name)

# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# Callback for early stopping
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True)

# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=6,
                              verbose=1,
                              min_delta=0.0001)

# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, reduce_lr, csv_logger]  # Adjusted as per your use-case

train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

history = model.fit(
    train_generator,
    steps_per_epoch=train_steps_per_epoch,
    epochs=100,
    validation_data=validation_generator,
    validation_steps=validation_steps_epoch,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 359/359 [==============================] - ETA: 0s - loss: 12.4914 - accuracy: 0.2222
# Epoch 1: val_loss improved from inf to 12.24442, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 154s 423ms/step - loss: 12.4914 - accuracy: 0.2222 - val_loss: 12.2444 - val_accuracy: 0.1731 - lr: 1.0000e-04
# Epoch 2/100
# 359/359 [==============================] - ETA: 0s - loss: 10.2318 - accuracy: 0.2406
# Epoch 2: val_loss improved from 12.24442 to 9.86924, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 152s 424ms/step - loss: 10.2318 - accuracy: 0.2406 - val_loss: 9.8692 - val_accuracy: 0.2352 - lr: 1.0000e-04
# Epoch 3/100
# 359/359 [==============================] - ETA: 0s - loss: 8.1211 - accuracy: 0.2471
# Epoch 3: val_loss improved from 9.86924 to 7.60296, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 152s 425ms/step - loss: 8.1211 - accuracy: 0.2471 - val_loss: 7.6030 - val_accuracy: 0.2343 - lr: 1.0000e-04
# Epoch 4/100
# 359/359 [==============================] - ETA: 0s - loss: 6.3018 - accuracy: 0.2541
# Epoch 4: val_loss improved from 7.60296 to 5.84469, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 151s 421ms/step - loss: 6.3018 - accuracy: 0.2541 - val_loss: 5.8447 - val_accuracy: 0.2475 - lr: 1.0000e-04
# Epoch 5/100
# 359/359 [==============================] - ETA: 0s - loss: 4.8893 - accuracy: 0.2594
# Epoch 5: val_loss improved from 5.84469 to 4.31459, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 152s 422ms/step - loss: 4.8893 - accuracy: 0.2594 - val_loss: 4.3146 - val_accuracy: 0.2578 - lr: 1.0000e-04
# Epoch 6/100
# 359/359 [==============================] - ETA: 0s - loss: 3.8551 - accuracy: 0.2682
# Epoch 6: val_loss improved from 4.31459 to 3.47919, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 152s 423ms/step - loss: 3.8551 - accuracy: 0.2682 - val_loss: 3.4792 - val_accuracy: 0.2855 - lr: 1.0000e-04
# Epoch 7/100
# 359/359 [==============================] - ETA: 0s - loss: 3.1311 - accuracy: 0.2852
# Epoch 7: val_loss improved from 3.47919 to 2.86841, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 153s 426ms/step - loss: 3.1311 - accuracy: 0.2852 - val_loss: 2.8684 - val_accuracy: 0.2588 - lr: 1.0000e-04
# Epoch 8/100
# 359/359 [==============================] - ETA: 0s - loss: 2.6456 - accuracy: 0.3040
# Epoch 8: val_loss improved from 2.86841 to 2.54308, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 151s 420ms/step - loss: 2.6456 - accuracy: 0.3040 - val_loss: 2.5431 - val_accuracy: 0.3081 - lr: 1.0000e-04
# Epoch 9/100
# 359/359 [==============================] - ETA: 0s - loss: 2.3115 - accuracy: 0.3282
# Epoch 9: val_loss improved from 2.54308 to 2.22732, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 151s 420ms/step - loss: 2.3115 - accuracy: 0.3282 - val_loss: 2.2273 - val_accuracy: 0.3282 - lr: 1.0000e-04
# Epoch 10/100
# 359/359 [==============================] - ETA: 0s - loss: 2.0817 - accuracy: 0.3598
# Epoch 10: val_loss improved from 2.22732 to 2.01601, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 151s 420ms/step - loss: 2.0817 - accuracy: 0.3598 - val_loss: 2.0160 - val_accuracy: 0.3691 - lr: 1.0000e-04
# Epoch 11/100
# 359/359 [==============================] - ETA: 0s - loss: 1.9222 - accuracy: 0.3929
# Epoch 11: val_loss improved from 2.01601 to 1.85441, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 150s 419ms/step - loss: 1.9222 - accuracy: 0.3929 - val_loss: 1.8544 - val_accuracy: 0.3964 - lr: 1.0000e-04
# Epoch 12/100
# 359/359 [==============================] - ETA: 0s - loss: 1.7883 - accuracy: 0.4255
# Epoch 12: val_loss improved from 1.85441 to 1.74355, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 150s 418ms/step - loss: 1.7883 - accuracy: 0.4255 - val_loss: 1.7435 - val_accuracy: 0.4276 - lr: 1.0000e-04
# Epoch 13/100
# 359/359 [==============================] - ETA: 0s - loss: 1.7056 - accuracy: 0.4440
# Epoch 13: val_loss improved from 1.74355 to 1.63853, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 151s 421ms/step - loss: 1.7056 - accuracy: 0.4440 - val_loss: 1.6385 - val_accuracy: 0.4616 - lr: 1.0000e-04
# Epoch 14/100
# 359/359 [==============================] - ETA: 0s - loss: 1.6375 - accuracy: 0.4649
# Epoch 14: val_loss improved from 1.63853 to 1.58920, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 152s 424ms/step - loss: 1.6375 - accuracy: 0.4649 - val_loss: 1.5892 - val_accuracy: 0.4778 - lr: 1.0000e-04
# Epoch 15/100
# 359/359 [==============================] - ETA: 0s - loss: 1.5870 - accuracy: 0.4753
# Epoch 15: val_loss did not improve from 1.58920
# 359/359 [==============================] - 150s 417ms/step - loss: 1.5870 - accuracy: 0.4753 - val_loss: 1.6437 - val_accuracy: 0.4449 - lr: 1.0000e-04
# Epoch 16/100
# 359/359 [==============================] - ETA: 0s - loss: 1.5428 - accuracy: 0.4930
# Epoch 16: val_loss improved from 1.58920 to 1.51330, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 151s 420ms/step - loss: 1.5428 - accuracy: 0.4930 - val_loss: 1.5133 - val_accuracy: 0.4881 - lr: 1.0000e-04
# Epoch 17/100
# 359/359 [==============================] - ETA: 0s - loss: 1.5067 - accuracy: 0.5047
# Epoch 17: val_loss did not improve from 1.51330
# 359/359 [==============================] - 150s 418ms/step - loss: 1.5067 - accuracy: 0.5047 - val_loss: 1.5250 - val_accuracy: 0.4966 - lr: 1.0000e-04
# Epoch 18/100
# 359/359 [==============================] - ETA: 0s - loss: 1.4694 - accuracy: 0.5151
# Epoch 18: val_loss improved from 1.51330 to 1.50897, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 150s 417ms/step - loss: 1.4694 - accuracy: 0.5151 - val_loss: 1.5090 - val_accuracy: 0.4916 - lr: 1.0000e-04
# Epoch 19/100
# 359/359 [==============================] - ETA: 0s - loss: 1.4474 - accuracy: 0.5203
# Epoch 19: val_loss improved from 1.50897 to 1.42069, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 151s 420ms/step - loss: 1.4474 - accuracy: 0.5203 - val_loss: 1.4207 - val_accuracy: 0.5262 - lr: 1.0000e-04
# Epoch 20/100
# 359/359 [==============================] - ETA: 0s - loss: 1.4239 - accuracy: 0.5280
# Epoch 20: val_loss improved from 1.42069 to 1.41116, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 151s 421ms/step - loss: 1.4239 - accuracy: 0.5280 - val_loss: 1.4112 - val_accuracy: 0.5236 - lr: 1.0000e-04
# Epoch 21/100
# 359/359 [==============================] - ETA: 0s - loss: 1.4106 - accuracy: 0.5277
# Epoch 21: val_loss did not improve from 1.41116
# 359/359 [==============================] - 149s 416ms/step - loss: 1.4106 - accuracy: 0.5277 - val_loss: 1.4920 - val_accuracy: 0.4975 - lr: 1.0000e-04
# Epoch 22/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3960 - accuracy: 0.5368
# Epoch 22: val_loss improved from 1.41116 to 1.39410, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 149s 415ms/step - loss: 1.3960 - accuracy: 0.5368 - val_loss: 1.3941 - val_accuracy: 0.5236 - lr: 1.0000e-04
# Epoch 23/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3699 - accuracy: 0.5443
# Epoch 23: val_loss did not improve from 1.39410
# 359/359 [==============================] - 151s 421ms/step - loss: 1.3699 - accuracy: 0.5443 - val_loss: 1.4016 - val_accuracy: 0.5341 - lr: 1.0000e-04
# Epoch 24/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3636 - accuracy: 0.5501
# Epoch 24: val_loss improved from 1.39410 to 1.36022, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 152s 422ms/step - loss: 1.3636 - accuracy: 0.5501 - val_loss: 1.3602 - val_accuracy: 0.5478 - lr: 1.0000e-04
# Epoch 25/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3493 - accuracy: 0.5520
# Epoch 25: val_loss improved from 1.36022 to 1.32942, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 151s 421ms/step - loss: 1.3493 - accuracy: 0.5520 - val_loss: 1.3294 - val_accuracy: 0.5588 - lr: 1.0000e-04
# Epoch 26/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3384 - accuracy: 0.5571
# Epoch 26: val_loss did not improve from 1.32942
# 359/359 [==============================] - 149s 415ms/step - loss: 1.3384 - accuracy: 0.5571 - val_loss: 1.3958 - val_accuracy: 0.5335 - lr: 1.0000e-04
# Epoch 27/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3314 - accuracy: 0.5624
# Epoch 27: val_loss did not improve from 1.32942
# 359/359 [==============================] - 150s 417ms/step - loss: 1.3314 - accuracy: 0.5624 - val_loss: 1.3935 - val_accuracy: 0.5198 - lr: 1.0000e-04
# Epoch 28/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3229 - accuracy: 0.5620
# Epoch 28: val_loss improved from 1.32942 to 1.32575, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 150s 419ms/step - loss: 1.3229 - accuracy: 0.5620 - val_loss: 1.3258 - val_accuracy: 0.5513 - lr: 1.0000e-04
# Epoch 29/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3131 - accuracy: 0.5690
# Epoch 29: val_loss improved from 1.32575 to 1.29801, saving model to /content/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras
# 359/359 [==============================] - 150s 418ms/step - loss: 1.3131 - accuracy: 0.5690 - val_loss: 1.2980 - val_accuracy: 0.5755 - lr: 1.0000e-04
# Epoch 30/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3034 - accuracy: 0.5680
# Epoch 30: val_loss did not improve from 1.29801
# 359/359 [==============================] - 149s 415ms/step - loss: 1.3034 - accuracy: 0.5680 - val_loss: 1.4217 - val_accuracy: 0.5414 - lr: 1.0000e-04
# Epoch 31/100
# 359/359 [==============================] - ETA: 0s - loss: 1.3077 - accuracy: 0.5688
# Epoch 31: val_loss did not improve from 1.29801
# 359/359 [==============================] - 149s 414ms/step - loss: 1.3077 - accuracy: 0.5688 - val_loss: 1.3765 - val_accuracy: 0.5508 - lr: 1.0000e-04
# Epoch 32/100
# 359/359 [==============================] - ETA: 0s - loss: 1.2966 - accuracy: 0.5710
# Epoch 32: val_loss did not improve from 1.29801
# Restoring model weights from the end of the best epoch: 29.
# 359/359 [==============================] - 149s 415ms/step - loss: 1.2966 - accuracy: 0.5710 - val_loss: 1.3066 - val_accuracy: 0.5682 - lr: 1.0000e-04
# Epoch 32: early stopping

# %%
plot_training_history(history)

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 359/359 [==============================] - 23s 65ms/step - loss: 1.2418 - accuracy: 0.5907
# 113/113 [==============================] - 6s 52ms/step - loss: 1.2092 - accuracy: 0.6024
# final train accuracy = 59.07 , validation accuracy = 60.24

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=np.ceil(test_generator.samples/test_generator.batch_size)), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 113/113 [==============================] - 6s 52ms/step

# %%
# Printing the classification report
report = classification_report(true_classes,
                               predicted_classes,
                               target_names=class_labels,
                               zero_division=0)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.12      0.13      0.12       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.17      0.06      0.09      1024
#        happy       0.26      0.29      0.27      1774
#      neutral       0.17      0.24      0.20      1233
#          sad       0.18      0.15      0.17      1247
#     surprise       0.11      0.14      0.12       831
#
#     accuracy                           0.18      7178
#    macro avg       0.14      0.14      0.14      7178
# weighted avg       0.18      0.18      0.17      7178

# %% [markdown]
# # Model 3: Transfer Learning VGGNET

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Define paths to the train and validation directories
train_data_dir = '/content/fer2013/train'
test_data_dir = '/content/fer2013/test'

# validation_data_dir = '/content/emotion_detection_project/datasets/raw/test'

# Set some parameters
img_width, img_height = 224, 224  # Size of images
batch_size = 64
epochs = 10
num_classes = 7  # Update this based on the number of your classes

# Rescale the pixel values (0-255) to the [0, 1] interval
data_generator = ImageDataGenerator(
                                rescale = 1 / 255.,
                                rotation_range=10,
                                zoom_range=0.2,
                                width_shift_range=0.1,
                                height_shift_range=0.1,
                                horizontal_flip=True,
                                fill_mode='nearest',
                                # validation_split=0.2
                                )

test_preprocessor = ImageDataGenerator(
    rescale = 1 / 255.,
)

# Automatically retrieve images and their classes for train and validation sets
train_generator = data_generator.flow_from_directory(
                                train_data_dir,
                                target_size=(img_width, img_height),
                                batch_size=batch_size,
                                class_mode='categorical',
                                color_mode='rgb',
                                subset='training',
                                shuffle = True)

test_generator = test_preprocessor.flow_from_directory(
                                test_data_dir,
                                target_size=(img_width, img_height),
                                batch_size=batch_size,
                                class_mode='categorical',
                                color_mode='rgb',)
                                # subset='validation')
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
classes = 7

# Clear the previous TensorFlow sessionx
tf.keras.backend.clear_session()

# Load the VGG16 base model, excluding its top (fully connected) layers
vgg = VGG16(input_shape=(224, 224, 3), include_top=False, weights='imagenet')
vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 14714688 (56.13 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Make the specified layers non-trainable
for layer in vgg.layers[:-3]:
    layer.trainable = False

vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 4719616 (18.00 MB)
# Non-trainable params: 9995072 (38.13 MB)
# _________________________________________________________________

# %%
# Flattening the layer and adding custom Dense layers
x = Flatten()(vgg.output)

# Adding a fully connected layer with ReLU activation and He normal initializer
x = Dense(1024, activation='relu', kernel_initializer='he_normal')(x)
x = Dropout(0.5)(x)  # Adding dropout for regularization

x = Dense(512, activation='relu', kernel_initializer='he_normal')(x)
x = Dropout(0.5)(x)  # Adding dropout for regularization

# Adding the output layer with softmax activation
# Note: Adjust the number of units to match the number of classes you have
output = Dense(classes, activation='softmax', kernel_initializer='he_normal')(x)

# Creating the model
model = Model(inputs=vgg.input, outputs=output)

# Compile the model
model.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001, beta_1=0.9, beta_2=0.999, amsgrad=False),
              metrics=['accuracy'])

# Model summary to see all layers
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 1024)              25691136
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_1 (Dense)             (None, 512)               524800
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_2 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 40934215 (156.15 MB)
# Trainable params: 30939143 (118.02 MB)
# Non-trainable params: 9995072 (38.13 MB)
# _________________________________________________________________

# %%
# File path for the model checkpoint
cnn_path = '/content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning'
name = 'VGG16_Transfer_Learning.keras'
chk_path = os.path.join(cnn_path, name)

# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# Callback for early stopping
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=3,
                          verbose=1,
                          restore_best_weights=True)

# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=6,
                              verbose=1,
                              min_delta=0.0001)

# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, reduce_lr, csv_logger]  # Adjusted as per your use-case

train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
# validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

# %%
history = model.fit(train_generator,
                    steps_per_epoch=train_steps_per_epoch,
                    validation_data=test_generator,
                    validation_steps=test_steps_epoch,
                    epochs=5,
                    callbacks = callbacks)
# Out:
# Epoch 1/5
# 449/449 [==============================] - ETA: 0s - loss: 1.5838 - accuracy: 0.3836
# Epoch 1: val_loss improved from inf to 1.32849, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 782s 2s/step - loss: 1.5838 - accuracy: 0.3836 - val_loss: 1.3285 - val_accuracy: 0.4962 - lr: 1.0000e-04
# Epoch 2/5
# 449/449 [==============================] - ETA: 0s - loss: 1.3729 - accuracy: 0.4757
# Epoch 2: val_loss improved from 1.32849 to 1.23728, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 786s 2s/step - loss: 1.3729 - accuracy: 0.4757 - val_loss: 1.2373 - val_accuracy: 0.5284 - lr: 1.0000e-04
# Epoch 3/5
# 449/449 [==============================] - ETA: 0s - loss: 1.2955 - accuracy: 0.5072
# Epoch 3: val_loss improved from 1.23728 to 1.21591, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 789s 2s/step - loss: 1.2955 - accuracy: 0.5072 - val_loss: 1.2159 - val_accuracy: 0.5318 - lr: 1.0000e-04
# Epoch 4/5
# 449/449 [==============================] - ETA: 0s - loss: 1.2366 - accuracy: 0.5321
# Epoch 4: val_loss improved from 1.21591 to 1.17077, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 795s 2s/step - loss: 1.2366 - accuracy: 0.5321 - val_loss: 1.1708 - val_accuracy: 0.5496 - lr: 1.0000e-04
# Epoch 5/5
# 449/449 [==============================] - ETA: 0s - loss: 1.1939 - accuracy: 0.5498
# Epoch 5: val_loss improved from 1.17077 to 1.13207, saving model to /content/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras
# 449/449 [==============================] - 797s 2s/step - loss: 1.1939 - accuracy: 0.5498 - val_loss: 1.1321 - val_accuracy: 0.5666 - lr: 1.0000e-04

# %%
plot_training_history(history)

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 449/449 [==============================] - 552s 1s/step - loss: 1.1140 - accuracy: 0.5740
# 113/113 [==============================] - 127s 1s/step - loss: 1.1321 - accuracy: 0.5666
# final train accuracy = 57.40 , validation accuracy = 56.66

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=np.ceil(test_generator.samples/test_generator.batch_size)), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 113/113 [==============================] - 127s 1s/step

# %%
# Printing the classification report
report = classification_report(true_classes,
                               predicted_classes,
                               target_names=class_labels,
                               zero_division=0)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.13      0.10      0.11       958
#      disgust       0.00      0.00      0.00       111
#         fear       0.12      0.03      0.05      1024
#        happy       0.26      0.31      0.28      1774
#      neutral       0.17      0.25      0.21      1233
#          sad       0.18      0.20      0.19      1247
#     surprise       0.13      0.15      0.14       831
#
#     accuracy                           0.19      7178
#    macro avg       0.14      0.15      0.14      7178
# weighted avg       0.17      0.19      0.17      7178

# %% [markdown]
# # Model 4 : Transfer Leanring - ResNet50

# %%
train_dir = '/content/fer2013/train'
test_dir = '/content/fer2013/test'

# Data augmentation configuration for training data
train_datagen = ImageDataGenerator(rescale=1/255,                # Rescale pixel values to [0, 1]
                                  rotation_range=40,            # Randomly rotate images in the range (degrees, 0 to 180)
                                  width_shift_range=0.2,        # Randomly horizontally shift images
                                  height_shift_range=0.2,       # Randomly vertically shift images
                                  shear_range=0.2,              # Apply shearing transformations
                                  zoom_range=0.1,               # Randomly zoom image
                                  horizontal_flip=True,         # Randomly flip images horizontally
                                  fill_mode='nearest'           # Strategy used for filling in newly created pixels
                                )

# Rescaling for validation/test data (without further data augmentation)
test_datagen = ImageDataGenerator(
                                  rescale=1/255                 # Rescale pixel values to [0, 1]
                              )

# Creating data generators for training
train_generator = train_datagen.flow_from_directory(
                                                    train_dir,
                                                    target_size=(224, 224),       # Resize images to 224x224 for model input
                                                    color_mode='rgb',             # Images will be converted to RGB
                                                    class_mode='categorical',     # For multi-class classification
                                                    batch_size=32                 # Size of the batches of data
                                                )

# Creating data generators for testing/validation
test_generator = test_datagen.flow_from_directory(
                                                  test_dir,
                                                  target_size=(224, 224),       # Resize images to 224x224 for model input
                                                  color_mode='rgb',             # Images will be converted to RGB
                                                  class_mode='categorical',     # For multi-class classification
                                                  batch_size=32                 # Size of the batches of data
                                              )
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# # Introducing Class wieghts for imbalanced data

# %%
# Extract class labels for all instances in the training dataset
classes = np.array(train_generator.classes)

# Calculate class weights to handle imbalances in the training data
# 'balanced' mode automatically adjusts weights inversely proportional to class frequencies
class_weights = compute_class_weight(
    class_weight='balanced',  # Strategy to balance classes
    classes=np.unique(classes),  # Unique class labels
    y=classes  # Class labels for each instance in the training dataset
)

# Create a dictionary mapping class indices to their calculated weights
class_weights_dict = dict(enumerate(class_weights))

# Output the class weights dictionary
print("Class Weights Dictionary:", class_weights_dict)
# Out:
# Class Weights Dictionary: {0: 1.0266046844269623, 1: 9.406618610747051, 2: 1.0010460615781582, 3: 0.5684387684387684, 4: 0.8260394187886635, 5: 0.8491274770777877, 6: 1.293372978330405}

# %%
input_shape = (224, 224, 3)

base_model = ResNet50V2(include_top=False, weights='imagenet', input_shape=input_shape)

model = Sequential([
                    base_model,
                    BatchNormalization(),
                    GlobalAveragePooling2D(),
                    Dense(512, activation='relu'),
                    Dropout(0.1),
                    Dense(256, activation='relu'),
                    Dropout(0.1),
                    Dense(128, activation='relu'),
                    Dropout(0.1),
                    Dense(7, activation='softmax')
                  ])

optimizer = Adamax(learning_rate=0.0001)

model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94668760/94668760 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 7, 7, 2048)        23564800
#
#  batch_normalization (Batch  (None, 7, 7, 2048)        8192
#  Normalization)
#
#  global_average_pooling2d (  (None, 2048)              0
#  GlobalAveragePooling2D)
#
#  dense_3 (Dense)             (None, 512)               1049088
#
#  dropout_2 (Dropout)         (None, 512)               0
#
#  dense_4 (Dense)             (None, 256)               131328
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 128)               32896
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_6 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 24787207 (94.56 MB)
# Trainable params: 24737671 (94.37 MB)
# Non-trainable params: 49536 (193.50 KB)
# _________________________________________________________________

# %%
# File path for the model checkpoint
cnn_path = '/content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning'
name = 'ResNet50_Transfer_Learning.keras'
chk_path = os.path.join(cnn_path, name)

# Callback to save the model checkpoint
checkpoint = ModelCheckpoint(filepath=chk_path,
                             save_best_only=True,
                             verbose=1,
                             mode='min',
                             monitor='val_loss')

# Callback for early stopping
earlystop = EarlyStopping(monitor='val_loss',
                          min_delta=0,
                          patience=6,
                          verbose=1,
                          restore_best_weights=True)

# Callback to reduce learning rate
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.2,
                              patience=6,
                              verbose=1,
                              min_delta=0.0001)

# Callback to log training data to a CSV file
csv_logger = CSVLogger(os.path.join(cnn_path,'training.log'))

# Aggregating all callbacks into a list
callbacks = [checkpoint, earlystop, csv_logger]  # Adjusted as per your use-case

train_steps_per_epoch = train_generator.samples // train_generator.batch_size + 1
# validation_steps_epoch = validation_generator.samples // validation_generator.batch_size + 1
test_steps_epoch = test_generator.samples // test_generator.batch_size + 1

# %%
train_history = model.fit(
                          train_generator,
                          steps_per_epoch=200,
                          epochs=50,
                          validation_data=test_generator,
                          validation_steps=100,
                          class_weight=class_weights_dict,
                          callbacks = callbacks
                        )
# Out:
# Epoch 1/50
# 200/200 [==============================] - ETA: 0s - loss: 1.8811 - accuracy: 0.1985
# Epoch 1: val_loss improved from inf to 1.84353, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 378s 2s/step - loss: 1.8811 - accuracy: 0.1985 - val_loss: 1.8435 - val_accuracy: 0.2647
# Epoch 2/50
# 200/200 [==============================] - ETA: 0s - loss: 1.8129 - accuracy: 0.2783
# Epoch 2: val_loss improved from 1.84353 to 1.76292, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 364s 2s/step - loss: 1.8129 - accuracy: 0.2783 - val_loss: 1.7629 - val_accuracy: 0.3200
# Epoch 3/50
# 200/200 [==============================] - ETA: 0s - loss: 1.7386 - accuracy: 0.3221
# Epoch 3: val_loss improved from 1.76292 to 1.66915, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 361s 2s/step - loss: 1.7386 - accuracy: 0.3221 - val_loss: 1.6692 - val_accuracy: 0.3609
# Epoch 4/50
# 200/200 [==============================] - ETA: 0s - loss: 1.7169 - accuracy: 0.3416
# Epoch 4: val_loss improved from 1.66915 to 1.53598, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 362s 2s/step - loss: 1.7169 - accuracy: 0.3416 - val_loss: 1.5360 - val_accuracy: 0.4156
# Epoch 5/50
# 200/200 [==============================] - ETA: 0s - loss: 1.5761 - accuracy: 0.3775
# Epoch 5: val_loss improved from 1.53598 to 1.42777, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 361s 2s/step - loss: 1.5761 - accuracy: 0.3775 - val_loss: 1.4278 - val_accuracy: 0.4616
# Epoch 6/50
# 200/200 [==============================] - ETA: 0s - loss: 1.5368 - accuracy: 0.4088
# Epoch 6: val_loss improved from 1.42777 to 1.36198, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 361s 2s/step - loss: 1.5368 - accuracy: 0.4088 - val_loss: 1.3620 - val_accuracy: 0.5003
# Epoch 7/50
# 200/200 [==============================] - ETA: 0s - loss: 1.4094 - accuracy: 0.4427
# Epoch 7: val_loss improved from 1.36198 to 1.32392, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 363s 2s/step - loss: 1.4094 - accuracy: 0.4427 - val_loss: 1.3239 - val_accuracy: 0.4956
# Epoch 8/50
# 200/200 [==============================] - ETA: 0s - loss: 1.4021 - accuracy: 0.4494
# Epoch 8: val_loss improved from 1.32392 to 1.25178, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 363s 2s/step - loss: 1.4021 - accuracy: 0.4494 - val_loss: 1.2518 - val_accuracy: 0.5163
# Epoch 9/50
# 200/200 [==============================] - ETA: 0s - loss: 1.3593 - accuracy: 0.4673
# Epoch 9: val_loss improved from 1.25178 to 1.22610, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 361s 2s/step - loss: 1.3593 - accuracy: 0.4673 - val_loss: 1.2261 - val_accuracy: 0.5372
# Epoch 10/50
# 200/200 [==============================] - ETA: 0s - loss: 1.3316 - accuracy: 0.4789
# Epoch 10: val_loss improved from 1.22610 to 1.20023, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 363s 2s/step - loss: 1.3316 - accuracy: 0.4789 - val_loss: 1.2002 - val_accuracy: 0.5416
# Epoch 11/50
# 200/200 [==============================] - ETA: 0s - loss: 1.2886 - accuracy: 0.5081
# Epoch 11: val_loss improved from 1.20023 to 1.17178, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 357s 2s/step - loss: 1.2886 - accuracy: 0.5081 - val_loss: 1.1718 - val_accuracy: 0.5522
# Epoch 12/50
# 200/200 [==============================] - ETA: 0s - loss: 1.2810 - accuracy: 0.5098
# Epoch 12: val_loss did not improve from 1.17178
# 200/200 [==============================] - 358s 2s/step - loss: 1.2810 - accuracy: 0.5098 - val_loss: 1.1779 - val_accuracy: 0.5534
# Epoch 13/50
# 200/200 [==============================] - ETA: 0s - loss: 1.2355 - accuracy: 0.5138
# Epoch 13: val_loss improved from 1.17178 to 1.13475, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 362s 2s/step - loss: 1.2355 - accuracy: 0.5138 - val_loss: 1.1348 - val_accuracy: 0.5697
# Epoch 14/50
# 200/200 [==============================] - ETA: 0s - loss: 1.2320 - accuracy: 0.5152
# Epoch 14: val_loss improved from 1.13475 to 1.13441, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 360s 2s/step - loss: 1.2320 - accuracy: 0.5152 - val_loss: 1.1344 - val_accuracy: 0.5766
# Epoch 15/50
# 200/200 [==============================] - ETA: 0s - loss: 1.1982 - accuracy: 0.5316
# Epoch 15: val_loss improved from 1.13441 to 1.12058, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 359s 2s/step - loss: 1.1982 - accuracy: 0.5316 - val_loss: 1.1206 - val_accuracy: 0.5619
# Epoch 16/50
# 200/200 [==============================] - ETA: 0s - loss: 1.2177 - accuracy: 0.5369
# Epoch 16: val_loss improved from 1.12058 to 1.11786, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 362s 2s/step - loss: 1.2177 - accuracy: 0.5369 - val_loss: 1.1179 - val_accuracy: 0.5700
# Epoch 17/50
# 200/200 [==============================] - ETA: 0s - loss: 1.1944 - accuracy: 0.5359
# Epoch 17: val_loss improved from 1.11786 to 1.09531, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 360s 2s/step - loss: 1.1944 - accuracy: 0.5359 - val_loss: 1.0953 - val_accuracy: 0.5825
# Epoch 18/50
# 200/200 [==============================] - ETA: 0s - loss: 1.1633 - accuracy: 0.5441
# Epoch 18: val_loss improved from 1.09531 to 1.07571, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 358s 2s/step - loss: 1.1633 - accuracy: 0.5441 - val_loss: 1.0757 - val_accuracy: 0.5962
# Epoch 19/50
# 200/200 [==============================] - ETA: 0s - loss: 1.1994 - accuracy: 0.5361
# Epoch 19: val_loss did not improve from 1.07571
# 200/200 [==============================] - 359s 2s/step - loss: 1.1994 - accuracy: 0.5361 - val_loss: 1.0886 - val_accuracy: 0.5900
# Epoch 20/50
# 200/200 [==============================] - ETA: 0s - loss: 1.1556 - accuracy: 0.5550
# Epoch 20: val_loss did not improve from 1.07571
# 200/200 [==============================] - 357s 2s/step - loss: 1.1556 - accuracy: 0.5550 - val_loss: 1.0927 - val_accuracy: 0.5909
# Epoch 21/50
# 200/200 [==============================] - ETA: 0s - loss: 1.0903 - accuracy: 0.5622
# Epoch 21: val_loss did not improve from 1.07571
# 200/200 [==============================] - 357s 2s/step - loss: 1.0903 - accuracy: 0.5622 - val_loss: 1.0825 - val_accuracy: 0.5931
# Epoch 22/50
# 200/200 [==============================] - ETA: 0s - loss: 1.1239 - accuracy: 0.5614
# Epoch 22: val_loss improved from 1.07571 to 1.05233, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 360s 2s/step - loss: 1.1239 - accuracy: 0.5614 - val_loss: 1.0523 - val_accuracy: 0.6122
# Epoch 23/50
# 200/200 [==============================] - ETA: 0s - loss: 1.0936 - accuracy: 0.5711
# Epoch 23: val_loss did not improve from 1.05233
# 200/200 [==============================] - 362s 2s/step - loss: 1.0936 - accuracy: 0.5711 - val_loss: 1.0782 - val_accuracy: 0.6062
# Epoch 24/50
# 200/200 [==============================] - ETA: 0s - loss: 1.0802 - accuracy: 0.5723
# Epoch 24: val_loss improved from 1.05233 to 1.03255, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 366s 2s/step - loss: 1.0802 - accuracy: 0.5723 - val_loss: 1.0325 - val_accuracy: 0.6266
# Epoch 25/50
# 200/200 [==============================] - ETA: 0s - loss: 1.0550 - accuracy: 0.5755
# Epoch 25: val_loss did not improve from 1.03255
# 200/200 [==============================] - 360s 2s/step - loss: 1.0550 - accuracy: 0.5755 - val_loss: 1.0400 - val_accuracy: 0.6025
# Epoch 26/50
# 200/200 [==============================] - ETA: 0s - loss: 1.0807 - accuracy: 0.5719
# Epoch 26: val_loss improved from 1.03255 to 1.02264, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 367s 2s/step - loss: 1.0807 - accuracy: 0.5719 - val_loss: 1.0226 - val_accuracy: 0.6169
# Epoch 27/50
# 200/200 [==============================] - ETA: 0s - loss: 1.0719 - accuracy: 0.5841
# Epoch 27: val_loss improved from 1.02264 to 1.01770, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 367s 2s/step - loss: 1.0719 - accuracy: 0.5841 - val_loss: 1.0177 - val_accuracy: 0.6203
# Epoch 28/50
# 200/200 [==============================] - ETA: 0s - loss: 1.0530 - accuracy: 0.5913
# Epoch 28: val_loss improved from 1.01770 to 1.00890, saving model to /content/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras
# 200/200 [==============================] - 363s 2s/step - loss: 1.0530 - accuracy: 0.5913 - val_loss: 1.0089 - val_accuracy: 0.6328
# Epoch 29/50
# 200/200 [==============================] - ETA: 0s - loss: 1.0252 - accuracy: 0.6002
# Epoch 29: val_loss did not improve from 1.00890
# 200/200 [==============================] - 359s 2s/step - loss: 1.0252 - accuracy: 0.6002 - val_loss: 1.0272 - val_accuracy: 0.6244
# Epoch 30/50
# 200/200 [==============================] - ETA: 0s - loss: 1.0015 - accuracy: 0.5977
# Epoch 30: val_loss did not improve from 1.00890
# 200/200 [==============================] - 364s 2s/step - loss: 1.0015 - accuracy: 0.5977 - val_loss: 1.0307 - val_accuracy: 0.6109
# Epoch 31/50
# 200/200 [==============================] - ETA: 0s - loss: 1.0353 - accuracy: 0.5998
# Epoch 31: val_loss did not improve from 1.00890
# 200/200 [==============================] - 367s 2s/step - loss: 1.0353 - accuracy: 0.5998 - val_loss: 1.0117 - val_accuracy: 0.6216
# Epoch 32/50
# 200/200 [==============================] - ETA: 0s - loss: 1.0001 - accuracy: 0.6123
# Epoch 32: val_loss did not improve from 1.00890
# 200/200 [==============================] - 362s 2s/step - loss: 1.0001 - accuracy: 0.6123 - val_loss: 1.0244 - val_accuracy: 0.6319
# Epoch 33/50
# 200/200 [==============================] - ETA: 0s - loss: 0.9846 - accuracy: 0.6129
# Epoch 33: val_loss did not improve from 1.00890
# 200/200 [==============================] - 364s 2s/step - loss: 0.9846 - accuracy: 0.6129 - val_loss: 1.0278 - val_accuracy: 0.6244
# Epoch 34/50
# 200/200 [==============================] - ETA: 0s - loss: 0.9905 - accuracy: 0.6041
# Epoch 34: val_loss did not improve from 1.00890
# Restoring model weights from the end of the best epoch: 28.
# 200/200 [==============================] - 362s 2s/step - loss: 0.9905 - accuracy: 0.6041 - val_loss: 1.0263 - val_accuracy: 0.6184
# Epoch 34: early stopping

# %%
plot_training_history(train_history)

# %%
train_loss, train_accu = model.evaluate(train_generator)
test_loss, test_accu = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}".format(train_accu*100, test_accu*100))
# Out:
# 898/898 [==============================] - 453s 504ms/step - loss: 1.0014 - accuracy: 0.6250
# 225/225 [==============================] - 91s 404ms/step - loss: 1.0310 - accuracy: 0.6206
# final train accuracy = 62.50 , validation accuracy = 62.06

# %%
# Assuming your true_classes and predicted_classes are already defined
true_classes = test_generator.classes
predicted_classes = np.argmax(model.predict(test_generator, steps=np.ceil(test_generator.samples/test_generator.batch_size)), axis=1)
class_labels = list(test_generator.class_indices.keys())

# Generate the confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Plotting with seaborn
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# 225/225 [==============================] - 89s 393ms/step

# %%
# Printing the classification report
report = classification_report(true_classes,
                               predicted_classes,
                               target_names=class_labels,
                               zero_division=0)
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.13      0.11      0.12       958
#      disgust       0.01      0.01      0.01       111
#         fear       0.15      0.12      0.13      1024
#        happy       0.23      0.21      0.22      1774
#      neutral       0.18      0.22      0.20      1233
#          sad       0.19      0.19      0.19      1247
#     surprise       0.12      0.13      0.13       831
#
#     accuracy                           0.17      7178
#    macro avg       0.14      0.14      0.14      7178
# weighted avg       0.17      0.17      0.17      7178

# %% [markdown]
# # AUC ROC plot for each class

# %%
true_labels = test_generator.classes
preds = model.predict(test_generator, steps=len(test_generator))
pred_labels = np.argmax(preds, axis=1)
classes=list(test_generator.class_indices.keys())
# Out:
# 225/225 [==============================] - 90s 398ms/step

# %%
y_encoded = pd.get_dummies(true_labels).astype(int).values
preds_encoded = pd.get_dummies(pred_labels).astype(int).values

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(7):
    fpr[i], tpr[i], _ = roc_curve(y_encoded[:,i], preds_encoded[:,i])
    roc_auc[i] = auc(fpr[i], tpr[i])

plt.figure(figsize=(10,5))
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2']
for i, color in enumerate(colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=2, label=f"ROC curve for {classes[i]} (area = {roc_auc[i]:0.2f})")

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')

# %% [markdown]
# # Save it to google drive

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os

# %%
# Define the paths to save the models
base_path = '/content/drive/MyDrive/FER_2013_Emotion_Detection'

# %%
custom_cnn_from_scratch_dir = os.path.join(base_path, 'Custom_CNN_From_Scratch')
custom_cnn_with_augmentation_dir = os.path.join(base_path, 'Custom_CNN_With_Augmentation')
vgg16_transfer_learning_dir = os.path.join(base_path, 'VGG16_Transfer_Learning')
resnet50_transfer_learning_dir = os.path.join(base_path, 'ResNet50_Transfer_Learning')

# %%
# Create directories if they do not exist
os.makedirs(custom_cnn_from_scratch_dir, exist_ok=True)
os.makedirs(custom_cnn_with_augmentation_dir, exist_ok=True)
os.makedirs(vgg16_transfer_learning_dir, exist_ok=True)
os.makedirs(resnet50_transfer_learning_dir, exist_ok=True)

# %%
# Define the full paths for the model files
custom_cnn_from_scratch_path = os.path.join(custom_cnn_from_scratch_dir, 'Custom_CNN_model.keras')
custom_cnn_with_augmentation_path = os.path.join(custom_cnn_with_augmentation_dir, 'Custom_CNN_augmented_model.keras')
vgg16_transfer_learning_path = os.path.join(vgg16_transfer_learning_dir, 'VGG16_Transfer_Learning.keras')
resnet50_transfer_learning_path = os.path.join(resnet50_transfer_learning_dir, 'ResNet50_Transfer_Learning.keras')

# %%
# Save models
model.save(custom_cnn_from_scratch_path)
model.save(custom_cnn_with_augmentation_path)
model.save(vgg16_transfer_learning_path)
model.save(resnet50_transfer_learning_path)

# %%
import os

# %%
# Check if the files exist
print("Custom CNN From Scratch model saved:", os.path.exists(custom_cnn_from_scratch_path))
# Out:
# Custom CNN From Scratch model saved: True

# %%
# List files in the directories to confirm
print("Files in Custom_CNN_From_Scratch directory:", os.listdir(custom_cnn_from_scratch_dir))
# Out:
# Files in Custom_CNN_From_Scratch directory: ['Custom_CNN_model.keras']

# %%
# For Loading all models
"""
from tensorflow.keras.models import load_model

# Define the paths where the models are saved
custom_cnn_from_scratch_path = '/content/drive/MyDrive/FER_2013_Emotion_Detection/Custom_CNN_From_Scratch/Custom_CNN_model.keras'
custom_cnn_with_augmentation_path = '/content/drive/MyDrive/FER_2013_Emotion_Detection/Custom_CNN_With_Augmentation/Custom_CNN_augmented_model.keras'
vgg16_transfer_learning_path = '/content/drive/MyDrive/FER_2013_Emotion_Detection/VGG16_Transfer_Learning/VGG16_Transfer_Learning.keras'
resnet50_transfer_learning_path = '/content/drive/MyDrive/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras'

# Load the models
model_custom_cnn_from_scratch = load_model(custom_cnn_from_scratch_path)
model_custom_cnn_with_augmentation = load_model(custom_cnn_with_augmentation_path)
model_vgg16_transfer_learning = load_model(vgg16_transfer_learning_path)
model_resnet50_transfer_learning = load_model(resnet50_transfer_learning_path)

"""

# %% [markdown]
# # Load the model best performing **model**

# %%
from tensorflow.keras.models import load_model

# %%
# Define the path to the best model
best_model_path = '/content/drive/MyDrive/FER_2013_Emotion_Detection/ResNet50_Transfer_Learning/ResNet50_Transfer_Learning.keras'

# %%
# Load the model
model = load_model(best_model_path)

# %% [markdown]
# # Prediction pipeline for best model

# %%
# Define emotion classes
Emotion_Classes = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# %%
def preprocess_image(image_path):
    # Load image in color mode (to get 3 channels)
    img = cv2.imread(image_path, cv2.IMREAD_COLOR)
    # Resize the image to the size expected by the model
    img = cv2.resize(img, (224, 224))
    # Normalize the pixel values
    img = img.astype('float32') / 255.0
    # Reshape to add batch dimension (1, 224, 224, 3)
    img = np.expand_dims(img, axis=0)
    return img

# %%
def predict_emotion(image_path):
    # Preprocess the image
    img = preprocess_image(image_path)
    # Make prediction
    predictions = model.predict(img)
    # Get the predicted class with the highest probability
    predicted_class = np.argmax(predictions, axis=1)[0]
    # Get the probability of the predicted class
    predicted_probability = np.max(predictions)
    return Emotion_Classes[predicted_class], predicted_probability

# %%
# Example usage
image_path = '/content/fer2013/test/fear/PublicTest_11909521.jpg'
predicted_emotion, probability = predict_emotion(image_path)
print(f"Predicted Emotion: {predicted_emotion}, Probability: {probability:.2f}")
# Out:
# 1/1 [==============================] - 0s 74ms/step
# Predicted Emotion: Fear, Probability: 0.41

# %%
# Plot the image with the prediction
img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
plt.imshow(img, cmap='gray')
plt.title(f"Predicted: {predicted_emotion} ({probability:.2f})")
plt.axis('off')
plt.show()
